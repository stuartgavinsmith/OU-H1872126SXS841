# %% [markdown]
# # Venus Atmospheric Modelling - Pioneer Data
# The Open University<br>
# Module SXS841 Masters level project in physical sciences<br>
# ***
# End of Module Assignment (EMA) 01<br>
# Stuart Gavin Smith<br>
# H1872126<br>
# 01 January 2025<br>
# Version:1.0<br>
# ***

# %% [raw]
# The Pioneer Venus data is available on an Internet server at the following URL:
#
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/
#
# Multiprobes Atmospheric Structure (LAS/SAS) Data Collection
#
# Format: GRT(HR:MIN),GRT(SEC),ALT(KM),P(BARS),T(DEG K),RHO(KG/M3),ZETA
#
# names=['GRT-HR-MIN', 'GRT-SEC','ALT-KM','P-BARS','T-DEG-K','RHO-KG-M3','ZETA']
#
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/descent_low_atm/las_low_atm_state.csv
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/descent_low_atm/sas_day_low_atm_state.csv
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/descent_low_atm/sas_night_low_atm_state.csv
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/descent_low_atm/sas_north_low_atm_state.csv
#
# Format: ALT(KM),RHO(KG/M3),P(MB),T(DEG K)
#
# names=['ALT-KM','RHO-KG-M3','P-MB','T-DEG-K']
#
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/entry_high_atm/sas_night_high_atm_state.csv
#
# Format: GRT(HR MIN),GRT(SEC),ALT(KM),V(KM/S),GAM(DEG),RHO(KG/M3),P(MB),T(DEG K),COMMENT
#
# names=['GRT-HR-MIN', 'GRT-SEC','ALT-KM','V-KMS', 'GAM-DEG','RHO-KG-M3','P-MB','T-DEG-K','COMMENT']
#
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/entry_mid_atm/sas_day_mid_atm_state.csv
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/entry_mid_atm/sas_night_mid_atm_state.csv
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/entry_mid_atm/sas_north_mid_atm_state.csv
#
#
# Small Probes Net Flux Radiometers (SNFR) Data Collection (Day)
#
# Format: GRT-19H(MIN),Z(KM),P(BAR),TATM(K),SENSORT,FNET(W/M2),FCORR
# names=['GRT-19H-MIN', 'ALT-KM', 'P-BAR','TATM-K','SENSORT','FNET-W-M2','FCORR']
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_snfr/snfr_day_net_flux.csv
#
# Large Probe Solar Flux Radiometer (LSFR) Data Collection
#
# TIME PRESS   ALT                                FLUX
# (GRT) (ATM)  (KM)        -------VIS------  ----COMBINED----- ---------NB-------
#                          DOWN    UP   NET   DOWN    UP   NET   DOWN    UP   NET
#
# names=['GRT-HR-MIN','P-BAR','ALT-KM','VIS-D','VIS-U','VIS-N','COM-D','COM-U','COM-N','NB-D','NB-U','NB-N']
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_lsfr/lsfr_solar_flux.csv
#
#
# Large Probe Gas Chromatograph (LGC) Data Collection
#
# names=['Sample','GRT-HM','ALT-KM','P-BARS','P1','P2','P3','P4','CO2-PC','CO2-1','CO2-2','CO2-3','CO2-4','N2-PC','N2-1','N2-2','N2-3','N2-4','H2O-PC','H2O-1','H2O-2','H2O-3','H2O-4','O2-PPM','O2-1','O2-2','O2-3','O2-4','AR-PPM','AR-1','AR-2','AR-3','AR-4','CO-PPM','CO-1','CO-2','CO-3','CO-4','NE-PPM','NE-1','NE-2','NE-3','NE-4','SO2-PPM','SO2-1','SO2-2','SO2-3','SO2-4','H2','METHANE','KRYPTON','ETHELYNE','ETHANE','HYDROGEN-SULFIDE','CARBONYL-SULFIDE','PROPANE','NITROUS-OXIDE']
# https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_lgc/lgc_low_atm_comp.csv

# %%
import calendar
import datetime
import sys
import warnings
warnings.simplefilter('ignore', FutureWarning)
from pandas import *
from numpy import  *
# %matplotlib inline

print("==============================PIONEER ATMOSPHERE DATA==================================")

#Download the CSV data files as needed from the data collection
LAS_LOW_ATM ='https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/descent_low_atm/las_low_atm_state.csv'
SAS_DAY_LOW_ATM ='https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/descent_low_atm/sas_day_low_atm_state.csv'
SAS_NIGHT_LOW_ATM ='https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/descent_low_atm/sas_night_low_atm_state.csv'
SAS_NORTH_LOW_ATM ='https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/descent_low_atm/sas_north_low_atm_state.csv'
SAS_NIGHT_HIGH_ATM ='https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/entry_high_atm/sas_night_high_atm_state.csv'
SAS_DAY_MID_ATM ='https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/entry_mid_atm/sas_day_mid_atm_state.csv'
SAS_NIGHT_MID_ATM ='https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/entry_mid_atm/sas_night_mid_atm_state.csv'
SAS_NORTH_MID_ATM ='https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_atm_struct/entry_mid_atm/sas_north_mid_atm_state.csv'
SNFR_DAY_NET_FLUX = 'https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_snfr/snfr_day_net_flux.csv'
LSFR_SOLAR_FLUX = 'https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_lsfr/lsfr_solar_flux.csv'
LGC_LOW_ATM_COMP = 'https://atmos.nmsu.edu/PDS/data/PDS4/pv_sed_bundle/data_lgc/lgc_low_atm_comp.csv'

print("Downloading data...(1 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfA=read_csv(LAS_LOW_ATM, header=None,names=['GRT-HR-MIN', 'GRT-SEC','ALT-KM','P-BARS','T-DEG-K','RHO-KG-M3','ZETA'])
except:
    print("LAS_LOW_ATM Venus data does not exist, or some other error")
    Error = True
    exit()
    
#Add this data into the plotting data frame
dfALT_T = dfA[['ALT-KM', 'T-DEG-K']]
dfALT_P = dfA[['ALT-KM', 'P-BARS']]
dfALT_D = dfA[['ALT-KM', 'RHO-KG-M3']]

print("Downloading data...(2 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfB=read_csv(SAS_DAY_LOW_ATM, header=None,names=['GRT-HR-MIN', 'GRT-SEC','ALT-KM','P-BARS','T-DEG-K','RHO-KG-M3','ZETA'])
except:
    print("SAS_DAY_LOW_ATM Venus data does not exist, or some other error")
    Error = True
    exit()
    
#Add this data into the plotting data frame
dfALT_T = concat([dfB[['ALT-KM', 'T-DEG-K']], dfALT_T])
dfALT_P = concat([dfB[['ALT-KM', 'P-BARS']], dfALT_P])
dfALT_D = concat([dfB[['ALT-KM', 'RHO-KG-M3']], dfALT_D])

print("Downloading data...(3 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfC=read_csv(SAS_NIGHT_LOW_ATM, header=None,names=['GRT-HR-MIN', 'GRT-SEC','ALT-KM','P-BARS','T-DEG-K','RHO-KG-M3','ZETA'])
except:
    print("SAS_NIGHT_LOW_ATM Venus data does not exist, or some other error")
    Error = True
    exit()
    
#Add this data into the plotting data frame
dfALT_T = concat([dfC[['ALT-KM', 'T-DEG-K']], dfALT_T])
dfALT_P = concat([dfC[['ALT-KM', 'P-BARS']], dfALT_P])
dfALT_D = concat([dfC[['ALT-KM', 'RHO-KG-M3']], dfALT_D])

print("Downloading data...(4 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfD=read_csv(SAS_NORTH_LOW_ATM, header=None,names=['GRT-HR-MIN', 'GRT-SEC','ALT-KM','P-BARS','T-DEG-K','RHO-KG-M3','ZETA'])
except:
    print("SAS_NORTH_LOW_ATM Venus data does not exist, or some other error")
    Error = True
    exit()
    
#Add this data into the plotting data frame
dfALT_T = concat([dfD[['ALT-KM', 'T-DEG-K']], dfALT_T])
dfALT_P = concat([dfD[['ALT-KM', 'P-BARS']], dfALT_P])
dfALT_D = concat([dfD[['ALT-KM', 'RHO-KG-M3']], dfALT_D])

print("Downloading data...(5 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfE=read_csv(SAS_NIGHT_HIGH_ATM, header=None,names=(['ALT-KM','RHO-KG-M3','P-MB','T-DEG-K']))
except:
    print("SAS_NIGHT_HIGH_ATM Venus data does not exist, or some other error")
    Error = True
    exit()
    
#Add this data into the plotting data frame
dfALT_T = concat([dfE[['ALT-KM', 'T-DEG-K']], dfALT_T])
#convert MB to Bars
dfE['P-BARS'] = dfE['P-MB'] / 1000
dfALT_P = concat([dfE[['ALT-KM', 'P-BARS']], dfALT_P])
dfALT_D = concat([dfE[['ALT-KM', 'RHO-KG-M3']], dfALT_D])

print("Downloading data...(6 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfF=read_csv(SAS_DAY_MID_ATM, header=None,names=(['GRT-HR-MIN', 'GRT-SEC','ALT-KM','V-KMS', 'GAM-DEG','RHO-KG-M3','P-MB','T-DEG-K','COMMENT']))
except:
    print("SAS_DAY_MID_ATM Venus data does not exist, or some other error")
    Error = True
    exit()

#Add this data into the plotting data frame
dfALT_T = concat([dfF[['ALT-KM', 'T-DEG-K']], dfALT_T])
#convert MB to Bars
dfF['P-BARS'] = dfF['P-MB'] / 1000
dfALT_P = concat([dfF[['ALT-KM', 'P-BARS']], dfALT_P])
dfALT_D = concat([dfF[['ALT-KM', 'RHO-KG-M3']], dfALT_D])

print("Downloading data...(7 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfG=read_csv(SAS_NIGHT_MID_ATM, header=None,names=(['GRT-HR-MIN', 'GRT-SEC','ALT-KM','V-KMS', 'GAM-DEG','RHO-KG-M3','P-MB','T-DEG-K','COMMENT']))
except:
    print("SAS_NIGHT_MID_ATM Venus data does not exist, or some other error")
    Error = True
    exit()

#Add this data into the plotting data frame
dfALT_T = concat([dfG[['ALT-KM', 'T-DEG-K']], dfALT_T])
#convert MB to Bars
dfG['P-BARS'] = dfG['P-MB'] / 1000
dfALT_P = concat([dfG[['ALT-KM', 'P-BARS']], dfALT_P])
dfALT_D = concat([dfG[['ALT-KM', 'RHO-KG-M3']], dfALT_D])

print("Downloading data...(8 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfH=read_csv(SAS_NORTH_MID_ATM, header=None,names=(['GRT-HR-MIN', 'GRT-SEC','ALT-KM','V-KMS', 'GAM-DEG','RHO-KG-M3','P-MB','T-DEG-K','COMMENT']))
except:
    print("SAS_NORTH_MID_ATM Venus data does not exist, or some other error")
    Error = True
    exit()
    
#Add this data into the plotting data frame
dfALT_T = concat([dfH[['ALT-KM', 'T-DEG-K']], dfALT_T])
#convert MB to Bars
dfH['P-BARS'] = dfH['P-MB'] / 1000
dfALT_P = concat([dfH[['ALT-KM', 'P-BARS']], dfALT_P])
dfALT_D = concat([dfH[['ALT-KM', 'RHO-KG-M3']], dfALT_D])

print("Downloading data...(9 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfI=read_csv(SNFR_DAY_NET_FLUX, header=None,names=['GRT-19H-MIN', 'ALT-KM', 'P-BAR','TATM-K','SENSORT','FNET-W-M2','FCORR'])
except:
    print("SNFR_DAY_NET_FLUX Venus data does not exist, or some other error")
    Error = True
    exit()
    
#Add this data into the plotting data frame
dfALT_F = dfI[['ALT-KM', 'FCORR']]

print("Downloading data...(10 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfJ=read_csv(LSFR_SOLAR_FLUX, header=None,names=['GRT-HR-MIN','P-BAR','ALT-KM','VIS-D','VIS-U','VIS-N','COM-D','COM-U','COM-N','NB-D','NB-U','NB-N'])
except:
    print("LSFR_SOLAR_FLUX Venus data does not exist, or some other error")
    Error = True
    exit()
    
#Add this data into the plotting data frame
dfALT_S = dfJ[['ALT-KM', 'COM-U']]

print("Downloading data...(11 of 11)")

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfK=read_csv(LGC_LOW_ATM_COMP, header=None,names=['Sample','GRT-HM','ALT-KM','P-BARS','P1','P2','P3','P4','CO2-PC','CO2-1','CO2-2','CO2-3','CO2-4','N2-PC','N2-1','N2-2','N2-3','N2-4','H2O-PC','H2O-1','H2O-2','H2O-3','H2O-4','O2-PPM','O2-1','O2-2','O2-3','O2-4','AR-PPM','AR-1','AR-2','AR-3','AR-4','CO-PPM','CO-1','CO-2','CO-3','CO-4','NE-PPM','NE-1','NE-2','NE-3','NE-4','SO2-PPM','SO2-1','SO2-2','SO2-3','SO2-4','H2','METHANE','KRYPTON','ETHELYNE','ETHANE','HYDROGEN-SULFIDE','CARBONYL-SULFIDE','PROPANE','NITROUS-OXIDE'])
except:
    print("LGC_LOW_ATM_COMP Venus data does not exist, or some other error")
    Error = True
    exit()
    
#Add this data into the plotting data frame
dfALT_COMP_PC = dfK[['ALT-KM', 'CO2-PC','N2-PC','H2O-PC']]
dfALT_COMP_PPM = dfK[['ALT-KM', 'O2-PPM','AR-PPM','CO-PPM','NE-PPM','SO2-PPM','H2','METHANE','KRYPTON','ETHELYNE','ETHANE','HYDROGEN-SULFIDE','CARBONYL-SULFIDE','PROPANE','NITROUS-OXIDE']]
# Out:
# ==============================PIONEER ATMOSPHERE DATA==================================
# Downloading data...(1 of 11)
# Downloading data...(2 of 11)
# Downloading data...(3 of 11)
# Downloading data...(4 of 11)
# Downloading data...(5 of 11)
# Downloading data...(6 of 11)
# Downloading data...(7 of 11)
# Downloading data...(8 of 11)
# Downloading data...(9 of 11)
# Downloading data...(10 of 11)
# Downloading data...(11 of 11)

# %% [markdown]
# Plot the integrated atmospheric data

# %%
#Set the Graph Title
GraphTitle = 'Altitude v Temperature'

#Convert K to Degrees Celsius 
dfALT_T['T-DEG-C'] = dfALT_T['T-DEG-K']-273.15

#Remove negative altitudes 
condition  = (dfALT_T['ALT-KM'] < 0.0 )
dfALT_T.loc[condition, 'ALT-KM'] = 0

#Sort by altitude descending
dfALT_T.sort_values("ALT-KM", ascending=False)

#Plot Data Frame
plot = dfALT_T.plot(x='T-DEG-C', y='ALT-KM', s=0.25, grid=True, figsize=(5,5), kind='scatter',title=GraphTitle, xlabel="Temperature (Degrees C)", ylabel="Altitude (km)" )
fig = plot.get_figure()
fig.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\Fig_' + GraphTitle + '.png', dpi=300, bbox_inches='tight') 
   

#Set the Graph Title
GraphTitle = 'Altitude v Pressure'

#Remove negative altitudes 
condition  = (dfALT_P['ALT-KM'] < 0.0 )
dfALT_P.loc[condition, 'ALT-KM'] = 0

#Sort by altitude descending
dfALT_P.sort_values("ALT-KM", ascending=False)

#Plot Data Frame
plot = dfALT_P.plot(x='P-BARS', y='ALT-KM', s=0.25,  grid=True, figsize=(5,5), kind='scatter',title=GraphTitle, xlabel="Pressure (Bars)", ylabel="Altitude (km)" )
fig = plot.get_figure()
fig.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\Fig_' + GraphTitle + '.png', dpi=300, bbox_inches='tight') 


#Set the Graph Title
GraphTitle = 'Altitude v Density'

#Remove negative altitudes 
condition  = (dfALT_D['ALT-KM'] < 0.0 )
dfALT_D.loc[condition, 'ALT-KM'] = 0

#Sort by altitude descending
dfALT_D.sort_values("ALT-KM", ascending=False)

#Plot Data Frame
plot = dfALT_D.plot(x='RHO-KG-M3', y='ALT-KM', s=0.25,  grid=True, figsize=(5,5), kind='scatter',title=GraphTitle, xlabel="Density (kg/m3)", ylabel="Altitude (km)" )
fig = plot.get_figure()
fig.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\Fig_' + GraphTitle + '.png', dpi=300, bbox_inches='tight') 


#Set the Graph Title
GraphTitle = 'Altitude v Solar Flux Small'

#Sort by altitude descending
dfALT_F.sort_values("ALT-KM", ascending=False)

#Plot Data Frame
plot = dfALT_F.plot(x='FCORR', y='ALT-KM', s=0.25,  grid=True, figsize=(5,5), kind='scatter',title=GraphTitle, xlabel="Solar Flux (W/m2)", ylabel="Altitude (km)" )
fig = plot.get_figure()
fig.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\Fig_' + GraphTitle + '.png', dpi=300, bbox_inches='tight') 


#Set the Graph Title
GraphTitle = 'Altitude v Solar Flux Large'

#Sort by altitude descending
dfALT_S.sort_values("ALT-KM", ascending=False)

#Plot Data Frame
plot = dfALT_S.plot(x='COM-U', y='ALT-KM', s=0.25,  grid=True, figsize=(5,5), kind='scatter',title=GraphTitle, xlabel="Solar Flux (W/m2)", ylabel="Altitude (km)" )
fig = plot.get_figure()
fig.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\Fig_' + GraphTitle + '.png', dpi=300, bbox_inches='tight') 


#Set the Graph Title
GraphTitle = 'Composition %'

#Sort by altitude descending
dfALT_COMP_PC.sort_values("ALT-KM", ascending=False)

#Plot Data Frame
plot = dfALT_COMP_PC.plot(x='ALT-KM', y=['CO2-PC','N2-PC','H2O-PC'], grid=True, figsize=(5,5), kind='line',title=GraphTitle, xlabel="Altitude (km)", ylabel="Percent (%)" )
fig = plot.get_figure()
fig.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\Fig_' + GraphTitle + '.png', dpi=300, bbox_inches='tight') 


#Output the PPM data
print("Chemical Analysis of LGC (Parts Per Million)")
print("")
print(dfALT_COMP_PPM)


#Convert all values to float
dfALT_P = dfALT_P.astype(float)
dfALT_T = dfALT_T.astype(float)
dfALT_D = dfALT_D.astype(float)
dfALT_F = dfALT_F.astype(float)
dfALT_S = dfALT_S.astype(float)
dfALT_COMP_PC = dfALT_COMP_PC.astype(float)
dfALT_COMP_PPM = dfALT_COMP_PPM.astype(float)


#Store Data Frames
dfALT_P.to_csv(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\CSV_Exports\dfALT_P.csv', encoding='utf-8', index=False, float_format="%.12f")
dfALT_T.to_csv(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\CSV_Exports\dfALT_T.csv', encoding='utf-8', index=False, float_format="%.12f")
dfALT_D.to_csv(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\CSV_Exports\dfALT_D.csv', encoding='utf-8', index=False, float_format="%.12f")
dfALT_F.to_csv(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\CSV_Exports\dfALT_F.csv', encoding='utf-8', index=False, float_format="%.12f")
dfALT_S.to_csv(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\CSV_Exports\dfALT_S.csv', encoding='utf-8', index=False, float_format="%.12f")
dfALT_COMP_PC.to_csv(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\CSV_Exports\dfALT_COMP_PC.csv', encoding='utf-8', index=False, float_format="%.12f")
dfALT_COMP_PPM.to_csv(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\CSV_Exports\dfALT_COMP_PPM.csv', encoding='utf-8', index=False, float_format="%.12f")

print("==============================END OF DATA PROCESSING===================================")
# Out:
# Chemical Analyis of LGC (Parts Per Million)
#
#    ALT-KM  O2-PPM  AR-PPM  CO-PPM  NE-PPM  SO2-PPM     H2  METHANE  KRYPTON  \
# 0    51.6    43.6    60.5    32.2    8.00    600.0  200.0     10.0     40.0
# 1    41.7    16.0    63.8    30.2   10.60    176.0   70.0      3.0     10.0
# 2    21.6   888.0    67.2    19.9    4.31    185.0   10.0      0.6      2.0
#
#    ETHELYNE  ETHANE  HYDROGEN-SULFIDE  CARBONYL-SULFIDE  PROPANE  \
# 0      20.0    20.0              40.0              40.0     90.0
# 1       7.0     7.0              10.0              10.0     30.0
# 2       1.0     1.0               2.0               2.0      5.0
#
#    NITROUS-OXIDE
# 0          200.0
# 1           70.0
# 2           10.0
# ==============================END OF DATA PROCESSING===================================
