# %% [markdown]
# # Venus Atmospheric Modelling - Variable Entry Angles
# The Open University<br>
# Module SXS841 Masters level project in physical sciences<br>
# ***
# End of Module Assignment (EMA) 01<br>
# Stuart Gavin Smith<br>
# H1872126<br>
# 26 May 2025<br>
# Version:1.0 (Report)<br>
# ***

# %%
#%%capture cap
#Comment out the above line to view text in the output

import io

import numpy as np
import matplotlib.pyplot as plt
from pandas import *
from scipy import interpolate
from scipy.interpolate import interp1d
import datetime

#Ignore deprecated function on data frame append
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

#Use the data created in the atmospheric modelling 
ATM_CSV = r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\CSV_Exports\dfALT_D.csv'
ATP_CSV = r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Atmospheric Modelling\CSV_Exports\dfALT_T.csv'

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfA=read_csv(ATM_CSV, skiprows=1,names=['ALT-KM','RHO-KG-M3'])
except:
    print("ATM_CSV Venus data does not exist, or some other error")
    Error = True
    exit()

#Read CSV data into dataframe, on error, print warning and stop kernel.
try:
    dfT=read_csv(ATP_CSV, skiprows=1,names=['ALT-KM','T-DEG-K','T-DEG-C'])
except:
    print("ATP_CSV Venus data does not exist, or some other error")
    Error = True
    exit()

#Convert KM to metres
dfA['ALT-KM'] = dfA['ALT-KM'] * 1000.0
dfT['ALT-KM'] = dfT['ALT-KM'] * 1000.0

#Sort original data for plotting
dfA.sort_values("ALT-KM", ascending=True)
dfT.sort_values("ALT-KM", ascending=True)

#Model Constants
maxmetres = 200000 # model start altitude, 40km above interface

# Constants - Venus
g    = 8.87    # m/s^2 Venus Gravity 
R    = 6051800 # m equatorial mean radius
RHOs = 65      # kg/m^3 Atmospheric density at sea level 
Hs   = 15819   # m atmospheric scale height

#Constants - Pioneer Venus Large Probe
Rnose = 1.42 / 2.0        # m radius of Entry Probe at base
Reff = 0.36               # m effectice nose radius of Probe for entry heating 
CD  = 1.05                # Drag coefficient for a blunted cone
S  = np.pi*(Rnose*Rnose)  # m2 Cross-sectional area (m^2) of entry capsule (and heat shield)
m  = 316.5                # kg Entry mass (without ablative shield heating mass loss)

#Constants - flight path for Pioneer Venus Large Probe
y0 = 32.37               # Degrees entry angle in degrees
Ve = 11540               # m/s entry velocity m/s 
h  = 160000              # m atmospheric interface
r  = R + h               # m height from planetary centre

#Maximum number of model step iterations
aMaxMS = 30000000
  
#Set the step resoluton and initial altitude     
StepResolution = 1000.0 # milliseconds

print("==============================SIMULATION CONFIGURATION=================================")
print("")
print("= Drag Co-Efficients and Cross Sectional Area")
print("")
print("Probe CD (coef.drag)  : " + f'{CD:.4f}' )
print("Probe S (X section)   : " + f'{S:.4f}' + str(' m2'))
print("")
print("= Mass")
print("")
print("Probe Mass            : " + f'{m:.2f}' + str(' kg'))
print("")
print("= Ballistic Entry Characteristics")
print("")
print("Entry Velocity        : " + f'{Ve:.2f}' + str(' m/s'))
print("Start Altitude        : " + f'{maxmetres:.2f}' + str(' m'))
print("")
print("= Atmospheric and Planetary")
print("")
print("Atmosphere Interface  : " + f'{h:.2f}' + str(' m'))
print("Scale Height          : " + f'{Hs:.2f}' + str(' m'))
print("Gravity (Venus)       : " + f'{g:.2f}' + str(' m/s/s'))
print("Equatorial Mean Radius: " + f'{R:.2f}' + str(' m'))
print("")
print("= Simulation Events")
print("")
print("Max Simluation Steps  : " + f'{aMaxMS:.2f}' + str(' steps'))
print("Step Resolution       : " + f'{StepResolution:.2f}' + str(' [1000 = 1 second]'))
print("")


#Arrays to hold the atmospheric measurement models of Density and Temperature
densityX = np.linspace(0,maxmetres,maxmetres)
densityY = np.arange(maxmetres,dtype=float)
tempX = np.linspace(0,maxmetres,maxmetres)
tempY = np.arange(maxmetres,dtype=float)
densityY2 = np.arange(maxmetres,dtype=float)

# Function to find the nearest density value in the dataframe
def find_nearest_density(df, AltCol, DenCol, value):
    arrayalt = df[AltCol].values
    arrayrho = df[DenCol].values
    idx = (np.abs(arrayalt - (1.0*value))).argmin()
    return arrayrho[idx]

# Function to find the nearest temperature value in the dataframe
def find_nearest_temp(df, AltCol, TempCol, value):
    arrayalt = df[AltCol].values
    arraydegC = df[TempCol].values
    idx = (np.abs(arrayalt - (1.0*value))).argmin()
    return arraydegC[idx]

# Create a 1m density height model from measurements
for AltCount in range(maxmetres):
    nearest_density = find_nearest_density(dfA, 'ALT-KM', 'RHO-KG-M3',AltCount)
    densityY[AltCount] = nearest_density

# Create a 1m temperature height model from measurements
for AltCount in range(maxmetres):
    nearest_temp = find_nearest_temp(dfT, 'ALT-KM', 'T-DEG-C',AltCount)
    tempY[AltCount] = nearest_temp
    
#From mathematical means, create an atmosphere model for validation purposes
for AltCount in range(maxmetres):
      #ρ = ρ0 exp ( -h / H )
      densityY2[AltCount] = RHOs * np.exp(-(AltCount/Hs))

    
# Interpolate the 'step' changes to increase fidelity to 1m steps    
Y1 = densityY[0]
Y2 = 0.0
X1 = 0
X2 = 0

#For each metre of height, smooth (simple interpolation)
for AltCount in range(maxmetres):
    if Y1 != densityY[AltCount]:
        #A step change has been detected
        X2 = AltCount - 1
        Y2 = densityY[AltCount]

        #Calculate the scaling factor to apply (interpolate)
        Yfactor = (Y2-Y1)/(X2-X1+1)
        
        #Now interpolate between the 2 points
        for InterpCount in range(X2-X1+1):
            densityY[int(X1+InterpCount)] = Y1 + (Yfactor*InterpCount)
        
        #Start a new step 
        Y1 = densityY[AltCount]
        X1 = AltCount

# Interpolate the 'step' changes to increase fidelity to 1m steps    
Y1 = tempY[0]
Y2 = 0.0
X1 = 0
X2 = 0

#For each metre of height, smooth (simple interpolation so each metre of height has a value)
for AltCount in range(maxmetres):
    if Y1 != tempY[AltCount]:
        #A step change has been detected
        X2 = AltCount - 1
        Y2 = tempY[AltCount]

        #Calculate the scaling factor to apply (interpolate)
        Yfactor = (Y2-Y1)/(X2-X1+1)
        
        #Now interpolate between the 2 points
        for InterpCount in range(X2-X1+1):
            tempY[int(X1+InterpCount)] = Y1 + (Yfactor*InterpCount)
        
        #Start a new step 
        Y1 = tempY[AltCount]
        X1 = AltCount    

        
        
def StepModel(bUseMeasurements, EntryAngle, tempY, densityY, tempX, densityX, densityY2):

    #Entry Angle
    y0 = EntryAngle
    #Atmospheric Model or Measurement Basis
    UseMeasurements = bUseMeasurements

    
    #Set the 1st step conditions
    Alt = maxmetres - 1
    Vcurrent = Ve
    aStep = 0.0
    Acc = 0.0
    Drag = 0.0
    AngleD = 0.0
    VerticalD = 0.0
    VerticalDstep = 0.0
    HorizontalD = 0.0
    VerticalV = 0.0
    HorizontalV = 0.0
    RHOmd = 0.0
    Tempmd = 0.0
    TotalHeatLoad = 0.0
    qDotms = 0.0

    #Convert entry angle to radians
    gammaR = np.radians(y0)

    #Step model data frame
    dfStepModel = DataFrame(columns=['TimeMS','Alt','Acc','Drag','Velocity','VerticalV','HorizontalV','HorizontalD', 'VerticalD', 'AngleD', 'Density', 'Temperature', 'qDot'])

    #Peak Values and Time Markers
    PeakAcc = 0.0
    PeakAccTimeStep = 0.0
    PeakAccAltitude = 0.0
    PeakHeatFlux = 0.0
    PeakHeatFluxTimeStep = 0.0
    PeakHeatFluxAltitude = 0.0
    PeakTemp = -273.15
    PeakTempTimeStep = 0.0
    PeakDensity = 0.0
    PeakDensityTimeStep = 0.0
    LowestAltitude = Alt
    LowestAltitudeTimeStep = 0.0

    print("==================================SIMULATION START=====================================")
    StartTimeDate = datetime.datetime.now()

    #Create the step model
    for msCount in range(aMaxMS):

        #Exit if Probe hits the ground
        if Alt <= 0:
            print(f'{msCount/StepResolution:08.3f}'+ ' Hit ground, model stopping')        
            Alt = 0
            break;

        #calculate the velocity and displacement in the horizontal and vertical at end of step  
        AngleD = AngleD + (Vcurrent / StepResolution)
        VerticalDstep = abs((np.sin(gammaR) * (Vcurrent / StepResolution)))
        VerticalD = VerticalD + abs((np.sin(gammaR) * (Vcurrent / StepResolution)))
        HorizontalD = HorizontalD + (np.cos(gammaR) * (Vcurrent / StepResolution))
        VerticalV = np.abs(np.sin(gammaR) * Vcurrent)
        HorizontalV = np.abs(np.cos(gammaR) * Vcurrent)

        #Get the density of air for this altitude using measurements or calculate from equation         
        if UseMeasurements == True:
            RHOmd = densityY[int(Alt)]
        else:
            RHOmd = densityY2[int(Alt)]
           
        #Get the temperature for this altitude
        Tempmd = tempY[int(Alt)]

        #Calulate the deceleration due to drag force 
        Acc = 0.5 * RHOmd * ((CD*S)/m) * np.power(Vcurrent, 2)
        
        #Calculate the heating rate (Watts per cm2)
        qDot = (1.8960e-4 * np.power(Vcurrent,3) * np.sqrt(RHOmd/Reff)) / 10000.0
        
        #Total heat load is measured in Joules - adjust summing according to resolution 
        qDotms = qDot / StepResolution
        TotalHeatLoad = TotalHeatLoad + qDotms
        
        #Calculate the exit altitude
        Alt = Alt - VerticalDstep

        #Calculate the exit velocity along the path of entry of this step, decceleration acts over 1m-ms/1m-ms
        Vcurrent = Vcurrent - abs(Acc / StepResolution)

        #Store the step output states
        stepData = {'TimeMS':msCount,
                    'Alt' : Alt,
                    'Acc' : Acc,
                    'Drag' : Drag,
                    'Velocity' : Vcurrent,
                    'VerticalV' : VerticalV,
                    'HorizontalV' : HorizontalV,
                    'HorizontalD' : HorizontalD,
                    'VerticalD' : VerticalD,
                    'AngleD' : AngleD,
                    'Density' : RHOmd,
                    'Temperature' : Tempmd,
                    'qDot': qDot}
        dfStepModel = dfStepModel.append(stepData, ignore_index=True)

        #Store peak values and timestamps
        if PeakAcc < Acc:
            PeakAcc = Acc
            PeakAccTimeStep = msCount
            PeakAccAltitude = Alt

        if PeakHeatFlux < qDot:
            PeakHeatFlux = qDot
            PeakHeatFluxTimeStep = msCount
            PeakHeatFluxAltitude = Alt
        
        if PeakTemp < Tempmd:
            PeakTemp = Tempmd
            PeakTempTimeStep = msCount

        if PeakDensity < RHOmd:
            PeakDensity = RHOmd
            PeakDensityTimeStep = msCount

        if LowestAltitude > Alt:
            LowestAltitude = Alt
            LowestAltitudeTimeStep = msCount

        #Comfort Message whilst processing (1 second)
        if msCount % StepResolution == 0:
            print(f'{msCount/StepResolution:08.3f}'+ ' Reached altitude of ' + f'{Alt/1000:.2f}' + ' km')

        #Stop the model when velocity has fallen off to around windspeed (300 m/s)
        if Vcurrent < 300:
            #Exit the Loop 
            break;

        #End of Loop

    #Mark end of simulation
    EndTimeDate = datetime.datetime.now()
    TimeDifference = EndTimeDate - StartTimeDate
    RunTimeSeconds = TimeDifference.total_seconds()

    #Print summary
    print("")
    print("==================================SIMULATION ENDED=====================================")
    print("")

    print("====================================SUMMARY DATA=======================================")
    print("Start Time (real)     : " + str(StartTimeDate))
    print("End Time (real)       : " + str(EndTimeDate))
    print("Run Time (real)       : " + str(RunTimeSeconds) + str(' seconds'))
    print("Run Time (sim)        : " + f'{msCount/StepResolution:.2f}' + str(' seconds'))
    print("Velocity              : " + f'{Vcurrent:.2f}' + str(' m/s'))
    print("Angle Distance        : " + f'{AngleD / 1000.0:.2f}' + str(' km'))
    print("Acceleration          : " + f'{Acc / StepResolution / StepResolution:.2f}' + str(' m/s/s'))
    print("Vertical Velocity     : " + f'{VerticalV:.2f}' + str(' m/s'))
    print("Horizontal Velocity   : " + f'{HorizontalV:.2f}' + str(' m/s'))
    print("Vertical Distance     : " + f'{VerticalD / 1000.0:.2f}' + str(' km'))
    print("Horizontal Distance   : " + f'{HorizontalD / 1000.0:.2f}' + str(' km'))
    print("Max Deceleration      : " + f'{PeakAcc / g:.2f}' + str(' g [Venus]'))
    print("Max Deceleration Time : " + f'{PeakAccTimeStep/StepResolution:.2f}' + str(' seconds'))
    print("Max Deceleration Alt  : " + f'{PeakAccAltitude / 1000.0:.2f}' + str(' km'))
    print("Max Heat Flux         : " + f'{PeakHeatFlux:.2f}' + str(' W/cm2'))
    print("Max Heat Flux Time    : " + f'{PeakHeatFluxTimeStep/StepResolution:.2f}' + str(' seconds'))
    print("Max Heat Flux Alt     : " + f'{PeakHeatFluxAltitude / 1000.0:.2f}' + str(' km'))
    print("Max Temperature       : " + f'{PeakTemp:.2f}' + str(' Degrees C'))
    print("Max Temperature Time  : " + f'{PeakTempTimeStep/StepResolution:.2f}' + str(' seconds'))
    print("Max Density           : " + f'{PeakDensity:.4f}' + str(' kg/m3'))
    print("Max Density Time      : " + f'{PeakDensityTimeStep/StepResolution:.2f}' + str(' seconds'))
    print("Lowest Altitude       : " + f'{LowestAltitude / 1000.0:.2f}' + str(' km'))
    print("Lowest Altitude Time  : " + f'{LowestAltitudeTimeStep/StepResolution:.2f}' + str(' seconds'))
    print("=======================================================================================")

    print("")
    print("=========================================PLOT==========================================")
    print("")    

    #Plot the acceleration in g in seconds
    dfStepModel['TimeMS'] = dfStepModel['TimeMS'] / 1000
    dfStepModel['Acc'] = dfStepModel['Acc'] / g  
    plt.scatter(dfStepModel['TimeMS'],dfStepModel['Acc'], s=0.2, linewidth=0)
    if UseMeasurements == True:
        plt.title('Ballistic Entry - (De)Acceleration Measured: ' + str(y0))
    else:
        plt.title('Ballistic Entry - (De)Acceleration Numerical: ' + str(y0))
    plt.xlabel('Time (s)')
    plt.ylabel('Deceleration (g)')
    plt.grid(True)
    plt.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Entry Modelling\EntryAngle_VAL_g_' + str(int(y0)) + str(UseMeasurements) + '.png',dpi=300, bbox_inches='tight') 
    plt.show()
    
    #Smooth the y-values, for plotting purposes only
    smooth_yg = dfStepModel['Acc'].squeeze()
    smooth_yg = smooth_yg.rolling(window=1000).mean()
   
     #Plot the acceleration in g in seconds
    plt.scatter(dfStepModel['TimeMS'],smooth_yg, s=0.2, linewidth=0)
    if UseMeasurements == True:
        plt.title('Ballistic Entry - (De)Acceleration Measured - Smoothed: ' + str(y0))
    else:
        plt.title('Ballistic Entry - (De)Acceleration Numerical - Smoothed: ' + str(y0))
    plt.xlabel('Time (s)')
    plt.ylabel('Deceleration (g)')
    plt.grid(True)
    plt.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Entry Modelling\EntryAngle_VAL_g_smoothed_' + str(int(y0)) + str(UseMeasurements) + '.png',dpi=300, bbox_inches='tight') 
    plt.show()

    #Plot the heating rate in W/cm2 per second
    plt.scatter(dfStepModel['TimeMS'],dfStepModel['qDot'], s=0.2, linewidth=0)
    if UseMeasurements == True:
        plt.title('Ballistic Entry - Heating Rate: ' + str(y0))
    else:
        plt.title('Ballistic Entry - Heating Rate: ' + str(y0))
    plt.xlabel('Time (s)')
    plt.ylabel('Heating Rate (W/cm2)')
    plt.grid(True)
    plt.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Entry Modelling\EntryAngle_VAL_qdot_' + str(int(y0)) + str(UseMeasurements) + '.png',dpi=300, bbox_inches='tight') 
    plt.show()

    #Smooth the y-values, for plotting purposes only    
    smooth_yh = dfStepModel['qDot'].squeeze()
    smooth_yh = smooth_yh.rolling(window=1000).mean()    
    
    #Plot the heating rate in W/cm2 per second
    plt.scatter(dfStepModel['TimeMS'],smooth_yh, s=0.2, linewidth=0)
    if UseMeasurements == True:
        plt.title('Ballistic Entry - Heating Rate - Smoothed: ' + str(y0))
    else:
        plt.title('Ballistic Entry - Heating Rate - Smoothed: ' + str(y0))
    plt.xlabel('Time (s)')
    plt.ylabel('Heating Rate (W/cm2)')
    plt.grid(True)
    plt.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Entry Modelling\EntryAngle_VAL_qdot_smoothed_' + str(int(y0)) + str(UseMeasurements) + '.png',dpi=300, bbox_inches='tight') 
    plt.show()    
    
    # Max Acceleration (Validation) - numerical only
    if UseMeasurements == False:
        Beta = 1/Hs 
        amax = -((Beta*Ve*Ve)/(2*np.exp(1))*np.sin(gammaR))
        print("Numerical Acc. Peak   : " + f'{amax:.2f}' + ' m/s/s')
        print("Numerical Acc. Peak g : " + f'{amax / g:.2f}' + ' g')
    
    print("Total Heat Loading    : " + f'{TotalHeatLoad / 1000000.0:.4f}' + ' MJ/cm2')
    print("Smoothed Max g        : " + f'{smooth_yg.max():.4f}' + ' g')
    print("Smoothed Max Heat     : " + f'{smooth_yh.max():.4f}' + ' W/cm2')

    #Store Deceleration Data
    dfAlt_DecStore = dfStepModel[['TimeMS','Acc','qDot']]
    dfAlt_DecStore.to_csv(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Entry Modelling\EntryAngle_' + str(int(y0)) + str(UseMeasurements) + '.csv', encoding='utf-8', index=False)
    
    print("")
    print("====================================END OF SCRIPT======================================")
    print("") 

    return dfAlt_DecStore 
    #End of Step Model Function


#Run the step models - with measurements (Pioneer Venus is 32.37 degrrees entry angle) 
print("")
print("====================================Call Step TVP======================================")
print("")   
plotDataTVPT = StepModel(True, 32.37, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step T15======================================")
print("")   
plotDataT15 = StepModel(True, 15.0, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step T30======================================")
print("")   
plotDataT30 = StepModel(True, 30.0, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step T45======================================")
print("")   
plotDataT45 = StepModel(True,45, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step T60======================================")
print("")   
plotDataT60 = StepModel(True,60, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step T75======================================")
print("")   
plotDataT75 = StepModel(True,75, tempY, densityY, tempX, densityX, densityY2)

#Run the step models - using atmospheric scale model
print("")
print("====================================Call Step FVP======================================")
print("")   
plotDataTVPF = StepModel(False, 32.37, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step F15======================================")
print("")   
plotDataF15 = StepModel(False, 15.0, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step F30======================================")
print("")   
plotDataF30 = StepModel(False, 30.0, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step F45======================================")
print("")   
plotDataF45 = StepModel(False, 45.0, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step F60======================================")
print("")   
plotDataF60 = StepModel(False, 60.0, tempY, densityY, tempX, densityX, densityY2)
print("")
print("====================================Call Step F75======================================")
print("")   
plotDataF75 = StepModel(False, 75.0, tempY, densityY, tempX, densityX, densityY2)


 #Overlay Plot all the graphs
plt.figure(figsize=(12, 4))

smooth_yg = plotDataTVPT['Acc'].squeeze()
smooth_yg = smooth_yg.rolling(window=1000).mean()    
plt.scatter(plotDataTVPT['TimeMS'],smooth_yg, s=0.2, linewidth=0, label='32.37 degrees (Ref M)')

smooth_yg = plotDataT15['Acc'].squeeze()
smooth_yg = smooth_yg.rolling(window=1000).mean()    
plt.scatter(plotDataT15['TimeMS'],smooth_yg, s=0.2, linewidth=0, label='15 degrees (M)')

smooth_yg = plotDataT30['Acc'].squeeze()
smooth_yg = smooth_yg.rolling(window=1000).mean()    
plt.scatter(plotDataT30['TimeMS'],smooth_yg, s=0.2, linewidth=0, label='30 degrees (M)')

smooth_yg = plotDataT45['Acc'].squeeze()
smooth_yg = smooth_yg.rolling(window=1000).mean()    
plt.scatter(plotDataT45['TimeMS'],smooth_yg, s=0.2, linewidth=0, label='45 degrees (M)')

smooth_yg = plotDataT60['Acc'].squeeze()
smooth_yg = smooth_yg.rolling(window=1000).mean()    
plt.scatter(plotDataT60['TimeMS'],smooth_yg, s=0.2, linewidth=0, label='60 degrees (M)')

smooth_yg = plotDataT75['Acc'].squeeze()
smooth_yg = smooth_yg.rolling(window=1000).mean()    
plt.scatter(plotDataT75['TimeMS'],smooth_yg, s=0.2, linewidth=0, label='75 degrees (M)')

#Numerically derived density generates a smooth plot, no need to smooth
plt.scatter(plotDataTVPF['TimeMS'],plotDataTVPF['Acc'], s=0.2, linewidth=0, label='32.37 degrees (Ref S)')
plt.scatter(plotDataF15['TimeMS'],plotDataF15['Acc'], s=0.2, linewidth=0, label='15 degrees (S)')
plt.scatter(plotDataF30['TimeMS'],plotDataF30['Acc'], s=0.2, linewidth=0, label='30 degrees (S)')
plt.scatter(plotDataF45['TimeMS'],plotDataF45['Acc'], s=0.2, linewidth=0, label='45 degrees (S)')
plt.scatter(plotDataF60['TimeMS'],plotDataF60['Acc'], s=0.2, linewidth=0, label='60 degrees (S)')
plt.scatter(plotDataF75['TimeMS'],plotDataF75['Acc'], s=0.2, linewidth=0, label='75 degrees (S)')

plt.xlabel('Time (s)')
plt.ylabel('Deceleration (g Venus)')

lgnd = plt.legend(loc='upper right', title="Entry Angles", scatterpoints=1, fontsize=10)
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]
lgnd.legendHandles[3]._sizes = [30]
lgnd.legendHandles[4]._sizes = [30]
lgnd.legendHandles[5]._sizes = [30]
lgnd.legendHandles[6]._sizes = [30]
lgnd.legendHandles[7]._sizes = [30]
lgnd.legendHandles[8]._sizes = [30]
lgnd.legendHandles[9]._sizes = [30]
lgnd.legendHandles[10]._sizes = [30]
lgnd.legendHandles[11]._sizes = [30]

plt.grid(True)

plt.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Entry Modelling\EntryAnglesCombined_VAL_ACC.png',dpi=300, bbox_inches='tight') 

plt.show()


 #Overlay Plot all the graphs
plt.figure(figsize=(12, 4))

smooth_yh = plotDataTVPT['qDot'].squeeze()
smooth_yh = smooth_yh.rolling(window=1000).mean()    
plt.scatter(plotDataTVPT['TimeMS'],smooth_yh, s=0.2, linewidth=0, label='32.37 degrees (Ref M)')

smooth_yh = plotDataT15['qDot'].squeeze()
smooth_yh = smooth_yh.rolling(window=1000).mean()    
plt.scatter(plotDataT15['TimeMS'],smooth_yh, s=0.2, linewidth=0, label='15 degrees (M)')

smooth_yh = plotDataT30['qDot'].squeeze()
smooth_yh = smooth_yh.rolling(window=1000).mean()    
plt.scatter(plotDataT30['TimeMS'],smooth_yh, s=0.2, linewidth=0, label='30 degrees (M)')

smooth_yh = plotDataT45['qDot'].squeeze()
smooth_yh = smooth_yh.rolling(window=1000).mean()    
plt.scatter(plotDataT45['TimeMS'],smooth_yh, s=0.2, linewidth=0, label='45 degrees (M)')

smooth_yh = plotDataT60['qDot'].squeeze()
smooth_yh = smooth_yh.rolling(window=1000).mean()    
plt.scatter(plotDataT60['TimeMS'],smooth_yh, s=0.2, linewidth=0, label='60 degrees (M)')

smooth_yh = plotDataT75['qDot'].squeeze()
smooth_yh = smooth_yh.rolling(window=1000).mean()    
plt.scatter(plotDataT75['TimeMS'],smooth_yh, s=0.2, linewidth=0, label='75 degrees (M)')

#Numerically derived density generates a smooth plot, no need to smooth
plt.scatter(plotDataTVPF['TimeMS'],plotDataTVPF['qDot'], s=0.2, linewidth=0, label='32.37 degrees (Ref S)')
plt.scatter(plotDataF15['TimeMS'],plotDataF15['qDot'], s=0.2, linewidth=0, label='15 degrees (S)')
plt.scatter(plotDataF30['TimeMS'],plotDataF30['qDot'], s=0.2, linewidth=0, label='30 degrees (S)')
plt.scatter(plotDataF45['TimeMS'],plotDataF45['qDot'], s=0.2, linewidth=0, label='45 degrees (S)')
plt.scatter(plotDataF60['TimeMS'],plotDataF60['qDot'], s=0.2, linewidth=0, label='60 degrees (S)')
plt.scatter(plotDataF75['TimeMS'],plotDataF75['qDot'], s=0.2, linewidth=0, label='75 degrees (S)')

plt.xlabel('Time (s)')
plt.ylabel('Heating Rate (W/cm2)')

lgnd = plt.legend(loc='upper right', title="Entry Angles", scatterpoints=1, fontsize=10)
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]
lgnd.legendHandles[3]._sizes = [30]
lgnd.legendHandles[4]._sizes = [30]
lgnd.legendHandles[5]._sizes = [30]
lgnd.legendHandles[6]._sizes = [30]
lgnd.legendHandles[7]._sizes = [30]
lgnd.legendHandles[8]._sizes = [30]
lgnd.legendHandles[9]._sizes = [30]
lgnd.legendHandles[10]._sizes = [30]
lgnd.legendHandles[11]._sizes = [30]

plt.grid(True)

plt.savefig(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Entry Modelling\EntryAnglesCombined_VAL_QDOT.png',dpi=300, bbox_inches='tight') 

plt.show()
# Out:
# ==============================SIMULATION CONFIGURATION=================================
#
# = Drag Co-Efficients and Cross Sectional Area
#
# Probe CD (coef.drag)  : 1.0500
# Probe S (X section)   : 1.5837 m2
#
# = Mass
#
# Probe Mass            : 316.50 kg
#
# = Ballistic Entry Characteristics
#
# Entry Velocity        : 11540.00 m/s
# Start Altitude        : 200000.00 m
#
# = Atmospheric and Planetary
#
# Atmosphere Interface  : 160000.00 m
# Scale Height          : 15819.00 m
# Gravity (Venus)       : 8.87 m/s/s
# Equatorial Mean Radius: 6051800.00 m
#
# = Simulation Events
#
# Max Simluation Steps  : 30000000.00 steps
# Step Resolution       : 1000.00 [1000 = 1 second]
#
#
# ====================================Call Step TVP======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 193.81 km
# 0002.000 Reached altitude of 187.64 km
# 0003.000 Reached altitude of 181.46 km
# 0004.000 Reached altitude of 175.28 km
# 0005.000 Reached altitude of 169.10 km
# 0006.000 Reached altitude of 162.92 km
# 0007.000 Reached altitude of 156.74 km
# 0008.000 Reached altitude of 150.57 km
# 0009.000 Reached altitude of 144.39 km
# 0010.000 Reached altitude of 138.21 km
# 0011.000 Reached altitude of 132.03 km
# 0012.000 Reached altitude of 125.85 km
# 0013.000 Reached altitude of 119.67 km
# 0014.000 Reached altitude of 113.50 km
# 0015.000 Reached altitude of 107.32 km
# 0016.000 Reached altitude of 101.14 km
# 0017.000 Reached altitude of 94.98 km
# 0018.000 Reached altitude of 88.88 km
# 0019.000 Reached altitude of 83.05 km
# 0020.000 Reached altitude of 78.01 km
# 0021.000 Reached altitude of 74.33 km
# 0022.000 Reached altitude of 71.94 km
# 0023.000 Reached altitude of 70.40 km
# 0024.000 Reached altitude of 69.34 km
# 0025.000 Reached altitude of 68.54 km
# 0026.000 Reached altitude of 67.93 km
# 0027.000 Reached altitude of 67.44 km
# 0028.000 Reached altitude of 67.05 km
# 0029.000 Reached altitude of 66.73 km
# 0030.000 Reached altitude of 66.46 km
# 0031.000 Reached altitude of 66.23 km
# 0032.000 Reached altitude of 66.03 km
# 0033.000 Reached altitude of 65.86 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 19:58:26.354211
# End Time (real)       : 2025-06-04 19:58:59.106417
# Run Time (real)       : 32.752206 seconds
# Run Time (sim)        : 33.01 seconds
# Velocity              : 299.97 m/s
# Angle Distance        : 250.55 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 160.62 m/s
# Horizontal Velocity   : 253.39 m/s
# Vertical Distance     : 134.14 km
# Horizontal Distance   : 211.61 km
# Max Deceleration      : 357.66 g [Venus]
# Max Deceleration Time : 20.36 seconds
# Max Deceleration Alt  : 76.50 km
# Max Heat Flux         : 2730.60 W/cm2
# Max Heat Flux Time    : 19.11 seconds
# Max Heat Flux Alt     : 82.45 km
# Max Temperature       : -6.55 Degrees C
# Max Temperature Time  : 12.49 seconds
# Max Density           : 0.1672 kg/m3
# Max Density Time      : 32.17 seconds
# Lowest Altitude       : 65.86 km
# Lowest Altitude Time  : 33.01 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Total Heat Loading    : 0.0092 MJ/cm2
# Smoothed Max g        : 303.7078 g
# Smoothed Max Heat     : 2528.8210 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step T15======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 200.00 km
# 0001.000 Reached altitude of 197.01 km
# 0002.000 Reached altitude of 194.02 km
# 0003.000 Reached altitude of 191.04 km
# 0004.000 Reached altitude of 188.05 km
# 0005.000 Reached altitude of 185.06 km
# 0006.000 Reached altitude of 182.08 km
# 0007.000 Reached altitude of 179.09 km
# 0008.000 Reached altitude of 176.10 km
# 0009.000 Reached altitude of 173.12 km
# 0010.000 Reached altitude of 170.13 km
# 0011.000 Reached altitude of 167.14 km
# 0012.000 Reached altitude of 164.15 km
# 0013.000 Reached altitude of 161.17 km
# 0014.000 Reached altitude of 158.18 km
# 0015.000 Reached altitude of 155.19 km
# 0016.000 Reached altitude of 152.21 km
# 0017.000 Reached altitude of 149.22 km
# 0018.000 Reached altitude of 146.23 km
# 0019.000 Reached altitude of 143.25 km
# 0020.000 Reached altitude of 140.26 km
# 0021.000 Reached altitude of 137.27 km
# 0022.000 Reached altitude of 134.29 km
# 0023.000 Reached altitude of 131.30 km
# 0024.000 Reached altitude of 128.31 km
# 0025.000 Reached altitude of 125.33 km
# 0026.000 Reached altitude of 122.34 km
# 0027.000 Reached altitude of 119.35 km
# 0028.000 Reached altitude of 116.37 km
# 0029.000 Reached altitude of 113.38 km
# 0030.000 Reached altitude of 110.39 km
# 0031.000 Reached altitude of 107.41 km
# 0032.000 Reached altitude of 104.42 km
# 0033.000 Reached altitude of 101.44 km
# 0034.000 Reached altitude of 98.46 km
# 0035.000 Reached altitude of 95.49 km
# 0036.000 Reached altitude of 92.55 km
# 0037.000 Reached altitude of 89.65 km
# 0038.000 Reached altitude of 86.84 km
# 0039.000 Reached altitude of 84.20 km
# 0040.000 Reached altitude of 81.83 km
# 0041.000 Reached altitude of 79.78 km
# 0042.000 Reached altitude of 78.10 km
# 0043.000 Reached altitude of 76.75 km
# 0044.000 Reached altitude of 75.69 km
# 0045.000 Reached altitude of 74.84 km
# 0046.000 Reached altitude of 74.14 km
# 0047.000 Reached altitude of 73.58 km
# 0048.000 Reached altitude of 73.11 km
# 0049.000 Reached altitude of 72.72 km
# 0050.000 Reached altitude of 72.38 km
# 0051.000 Reached altitude of 72.09 km
# 0052.000 Reached altitude of 71.83 km
# 0053.000 Reached altitude of 71.60 km
# 0054.000 Reached altitude of 71.39 km
# 0055.000 Reached altitude of 71.21 km
# 0056.000 Reached altitude of 71.04 km
# 0057.000 Reached altitude of 70.89 km
# 0058.000 Reached altitude of 70.75 km
# 0059.000 Reached altitude of 70.62 km
# 0060.000 Reached altitude of 70.50 km
# 0061.000 Reached altitude of 70.38 km
# 0062.000 Reached altitude of 70.28 km
# 0063.000 Reached altitude of 70.18 km
# 0064.000 Reached altitude of 70.09 km
# 0065.000 Reached altitude of 70.00 km
# 0066.000 Reached altitude of 69.91 km
# 0067.000 Reached altitude of 69.83 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 19:59:00.416401
# End Time (real)       : 2025-06-04 20:00:33.197234
# Run Time (real)       : 92.780833 seconds
# Run Time (sim)        : 67.12 seconds
# Velocity              : 300.00 m/s
# Angle Distance        : 502.95 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 77.65 m/s
# Horizontal Velocity   : 289.79 m/s
# Vertical Distance     : 130.17 km
# Horizontal Distance   : 485.81 km
# Max Deceleration      : 172.49 g [Venus]
# Max Deceleration Time : 40.50 seconds
# Max Deceleration Alt  : 80.75 km
# Max Heat Flux         : 1965.11 W/cm2
# Max Heat Flux Time    : 38.39 seconds
# Max Heat Flux Alt     : 85.80 km
# Max Temperature       : -6.58 Degrees C
# Max Temperature Time  : 25.85 seconds
# Max Density           : 0.0634 kg/m3
# Max Density Time      : 59.52 seconds
# Lowest Altitude       : 69.83 km
# Lowest Altitude Time  : 67.12 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Total Heat Loading    : 0.0129 MJ/cm2
# Smoothed Max g        : 159.3776 g
# Smoothed Max Heat     : 1855.2840 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step T30======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 194.22 km
# 0002.000 Reached altitude of 188.45 km
# 0003.000 Reached altitude of 182.68 km
# 0004.000 Reached altitude of 176.91 km
# 0005.000 Reached altitude of 171.14 km
# 0006.000 Reached altitude of 165.37 km
# 0007.000 Reached altitude of 159.60 km
# 0008.000 Reached altitude of 153.83 km
# 0009.000 Reached altitude of 148.06 km
# 0010.000 Reached altitude of 142.29 km
# 0011.000 Reached altitude of 136.52 km
# 0012.000 Reached altitude of 130.75 km
# 0013.000 Reached altitude of 124.98 km
# 0014.000 Reached altitude of 119.21 km
# 0015.000 Reached altitude of 113.44 km
# 0016.000 Reached altitude of 107.67 km
# 0017.000 Reached altitude of 101.91 km
# 0018.000 Reached altitude of 96.15 km
# 0019.000 Reached altitude of 90.43 km
# 0020.000 Reached altitude of 84.89 km
# 0021.000 Reached altitude of 79.88 km
# 0022.000 Reached altitude of 75.95 km
# 0023.000 Reached altitude of 73.25 km
# 0024.000 Reached altitude of 71.47 km
# 0025.000 Reached altitude of 70.28 km
# 0026.000 Reached altitude of 69.40 km
# 0027.000 Reached altitude of 68.73 km
# 0028.000 Reached altitude of 68.20 km
# 0029.000 Reached altitude of 67.76 km
# 0030.000 Reached altitude of 67.40 km
# 0031.000 Reached altitude of 67.10 km
# 0032.000 Reached altitude of 66.84 km
# 0033.000 Reached altitude of 66.62 km
# 0034.000 Reached altitude of 66.43 km
# 0035.000 Reached altitude of 66.26 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:00:34.965672
# End Time (real)       : 2025-06-04 20:01:13.024649
# Run Time (real)       : 38.058977 seconds
# Run Time (sim)        : 35.59 seconds
# Velocity              : 299.98 m/s
# Angle Distance        : 267.66 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 150.01 m/s
# Horizontal Velocity   : 259.82 m/s
# Vertical Distance     : 133.83 km
# Horizontal Distance   : 231.80 km
# Max Deceleration      : 334.90 g [Venus]
# Max Deceleration Time : 21.84 seconds
# Max Deceleration Alt  : 76.50 km
# Max Heat Flux         : 2659.58 W/cm2
# Max Heat Flux Time    : 20.47 seconds
# Max Heat Flux Alt     : 82.45 km
# Max Temperature       : -6.69 Degrees C
# Max Temperature Time  : 13.38 seconds
# Max Density           : 0.1436 kg/m3
# Max Density Time      : 32.05 seconds
# Lowest Altitude       : 66.17 km
# Lowest Altitude Time  : 35.59 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Total Heat Loading    : 0.0095 MJ/cm2
# Smoothed Max g        : 287.2385 g
# Smoothed Max Heat     : 2465.1750 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step T45======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 191.83 km
# 0002.000 Reached altitude of 183.67 km
# 0003.000 Reached altitude of 175.51 km
# 0004.000 Reached altitude of 167.35 km
# 0005.000 Reached altitude of 159.19 km
# 0006.000 Reached altitude of 151.03 km
# 0007.000 Reached altitude of 142.87 km
# 0008.000 Reached altitude of 134.71 km
# 0009.000 Reached altitude of 126.55 km
# 0010.000 Reached altitude of 118.39 km
# 0011.000 Reached altitude of 110.23 km
# 0012.000 Reached altitude of 102.07 km
# 0013.000 Reached altitude of 93.93 km
# 0014.000 Reached altitude of 85.91 km
# 0015.000 Reached altitude of 78.60 km
# 0016.000 Reached altitude of 73.27 km
# 0017.000 Reached altitude of 70.16 km
# 0018.000 Reached altitude of 68.32 km
# 0019.000 Reached altitude of 67.13 km
# 0020.000 Reached altitude of 66.32 km
# 0021.000 Reached altitude of 65.76 km
# 0022.000 Reached altitude of 65.33 km
# 0023.000 Reached altitude of 64.99 km
# 0024.000 Reached altitude of 64.72 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:01:14.509609
# End Time (real)       : 2025-06-04 20:01:38.423898
# Run Time (real)       : 23.914289 seconds
# Run Time (sim)        : 24.87 seconds
# Velocity              : 299.97 m/s
# Angle Distance        : 191.60 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 212.15 m/s
# Horizontal Velocity   : 212.15 m/s
# Vertical Distance     : 135.48 km
# Horizontal Distance   : 135.48 km
# Max Deceleration      : 472.48 g [Venus]
# Max Deceleration Time : 15.77 seconds
# Max Deceleration Alt  : 74.30 km
# Max Heat Flux         : 3094.34 W/cm2
# Max Heat Flux Time    : 14.69 seconds
# Max Heat Flux Alt     : 80.75 km
# Max Temperature       : -6.65 Degrees C
# Max Temperature Time  : 9.46 seconds
# Max Density           : 0.2090 kg/m3
# Max Density Time      : 24.86 seconds
# Lowest Altitude       : 64.52 km
# Lowest Altitude Time  : 24.87 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Total Heat Loading    : 0.0080 MJ/cm2
# Smoothed Max g        : 388.3202 g
# Smoothed Max Heat     : 2826.7733 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step T60======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 190.00 km
# 0002.000 Reached altitude of 180.00 km
# 0003.000 Reached altitude of 170.01 km
# 0004.000 Reached altitude of 160.01 km
# 0005.000 Reached altitude of 150.02 km
# 0006.000 Reached altitude of 140.03 km
# 0007.000 Reached altitude of 130.03 km
# 0008.000 Reached altitude of 120.04 km
# 0009.000 Reached altitude of 110.04 km
# 0010.000 Reached altitude of 100.05 km
# 0011.000 Reached altitude of 90.10 km
# 0012.000 Reached altitude of 80.56 km
# 0013.000 Reached altitude of 73.17 km
# 0014.000 Reached altitude of 69.08 km
# 0015.000 Reached altitude of 66.89 km
# 0016.000 Reached altitude of 65.65 km
# 0017.000 Reached altitude of 64.87 km
# 0018.000 Reached altitude of 64.34 km
# 0019.000 Reached altitude of 63.94 km
# 0020.000 Reached altitude of 63.63 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:01:39.801740
# End Time (real)       : 2025-06-04 20:01:58.028799
# Run Time (real)       : 18.227059 seconds
# Run Time (sim)        : 20.32 seconds
# Velocity              : 299.98 m/s
# Angle Distance        : 157.56 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 259.84 m/s
# Horizontal Velocity   : 150.02 m/s
# Vertical Distance     : 136.45 km
# Horizontal Distance   : 78.78 km
# Max Deceleration      : 580.67 g [Venus]
# Max Deceleration Time : 12.95 seconds
# Max Deceleration Alt  : 73.45 km
# Max Heat Flux         : 3341.75 W/cm2
# Max Heat Flux Time    : 11.98 seconds
# Max Heat Flux Alt     : 80.74 km
# Max Temperature       : -6.72 Degrees C
# Max Temperature Time  : 7.72 seconds
# Max Density           : 0.2544 kg/m3
# Max Density Time      : 20.15 seconds
# Lowest Altitude       : 63.55 km
# Lowest Altitude Time  : 20.32 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Total Heat Loading    : 0.0073 MJ/cm2
# Smoothed Max g        : 460.1097 g
# Smoothed Max Heat     : 3042.6153 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step T75======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 188.84 km
# 0002.000 Reached altitude of 177.69 km
# 0003.000 Reached altitude of 166.55 km
# 0004.000 Reached altitude of 155.40 km
# 0005.000 Reached altitude of 144.25 km
# 0006.000 Reached altitude of 133.11 km
# 0007.000 Reached altitude of 121.96 km
# 0008.000 Reached altitude of 110.81 km
# 0009.000 Reached altitude of 99.67 km
# 0010.000 Reached altitude of 88.58 km
# 0011.000 Reached altitude of 78.18 km
# 0012.000 Reached altitude of 70.97 km
# 0013.000 Reached altitude of 67.36 km
# 0014.000 Reached altitude of 65.55 km
# 0015.000 Reached altitude of 64.54 km
# 0016.000 Reached altitude of 63.90 km
# 0017.000 Reached altitude of 63.44 km
# 0018.000 Reached altitude of 63.09 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:01:59.416867
# End Time (real)       : 2025-06-04 20:02:15.348734
# Run Time (real)       : 15.931867 seconds
# Run Time (sim)        : 18.28 seconds
# Velocity              : 299.99 m/s
# Angle Distance        : 141.82 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 289.83 m/s
# Horizontal Velocity   : 77.66 m/s
# Vertical Distance     : 136.99 km
# Horizontal Distance   : 36.71 km
# Max Deceleration      : 649.45 g [Venus]
# Max Deceleration Time : 11.58 seconds
# Max Deceleration Alt  : 73.45 km
# Max Heat Flux         : 3547.70 W/cm2
# Max Heat Flux Time    : 11.04 seconds
# Max Heat Flux Alt     : 77.79 km
# Max Temperature       : -6.69 Degrees C
# Max Temperature Time  : 6.93 seconds
# Max Density           : 0.2838 kg/m3
# Max Density Time      : 18.19 seconds
# Lowest Altitude       : 63.01 km
# Lowest Altitude Time  : 18.28 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Total Heat Loading    : 0.0070 MJ/cm2
# Smoothed Max g        : 500.8764 g
# Smoothed Max Heat     : 3152.0193 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step FVP======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 193.84 km
# 0002.000 Reached altitude of 187.74 km
# 0003.000 Reached altitude of 181.72 km
# 0004.000 Reached altitude of 175.83 km
# 0005.000 Reached altitude of 170.09 km
# 0006.000 Reached altitude of 164.57 km
# 0007.000 Reached altitude of 159.33 km
# 0008.000 Reached altitude of 154.44 km
# 0009.000 Reached altitude of 149.95 km
# 0010.000 Reached altitude of 145.91 km
# 0011.000 Reached altitude of 142.32 km
# 0012.000 Reached altitude of 139.17 km
# 0013.000 Reached altitude of 136.44 km
# 0014.000 Reached altitude of 134.08 km
# 0015.000 Reached altitude of 132.04 km
# 0016.000 Reached altitude of 130.27 km
# 0017.000 Reached altitude of 128.73 km
# 0018.000 Reached altitude of 127.38 km
# 0019.000 Reached altitude of 126.20 km
# 0020.000 Reached altitude of 125.15 km
# 0021.000 Reached altitude of 124.22 km
# 0022.000 Reached altitude of 123.38 km
# 0023.000 Reached altitude of 122.62 km
# 0024.000 Reached altitude of 121.94 km
# 0025.000 Reached altitude of 121.32 km
# 0026.000 Reached altitude of 120.75 km
# 0027.000 Reached altitude of 120.22 km
# 0028.000 Reached altitude of 119.74 km
# 0029.000 Reached altitude of 119.29 km
# 0030.000 Reached altitude of 118.88 km
# 0031.000 Reached altitude of 118.49 km
# 0032.000 Reached altitude of 118.13 km
# 0033.000 Reached altitude of 117.78 km
# 0034.000 Reached altitude of 117.46 km
# 0035.000 Reached altitude of 117.16 km
# 0036.000 Reached altitude of 116.88 km
# 0037.000 Reached altitude of 116.61 km
# 0038.000 Reached altitude of 116.35 km
# 0039.000 Reached altitude of 116.11 km
# 0040.000 Reached altitude of 115.88 km
# 0041.000 Reached altitude of 115.66 km
# 0042.000 Reached altitude of 115.44 km
# 0043.000 Reached altitude of 115.24 km
# 0044.000 Reached altitude of 115.05 km
# 0045.000 Reached altitude of 114.86 km
# 0046.000 Reached altitude of 114.69 km
# 0047.000 Reached altitude of 114.51 km
# 0048.000 Reached altitude of 114.35 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:02:16.663639
# End Time (real)       : 2025-06-04 20:03:15.235786
# Run Time (real)       : 58.572147 seconds
# Run Time (sim)        : 48.15 seconds
# Velocity              : 299.99 m/s
# Angle Distance        : 160.02 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 160.62 m/s
# Horizontal Velocity   : 253.39 m/s
# Vertical Distance     : 85.67 km
# Horizontal Distance   : 135.16 km
# Max Deceleration      : 96.58 g [Venus]
# Max Deceleration Time : 10.01 seconds
# Max Deceleration Alt  : 145.87 km
# Max Heat Flux         : 1433.41 W/cm2
# Max Heat Flux Time    : 6.25 seconds
# Max Heat Flux Alt     : 163.22 km
# Max Temperature       : -6.55 Degrees C
# Max Temperature Time  : 22.76 seconds
# Max Density           : 0.0472 kg/m3
# Max Density Time      : 48.15 seconds
# Lowest Altitude       : 114.33 km
# Lowest Altitude Time  : 48.15 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Numerical Acc. Peak   : -829.04 m/s/s
# Numerical Acc. Peak g : -93.47 g
# Total Heat Loading    : 0.0146 MJ/cm2
# Smoothed Max g        : 96.3405 g
# Smoothed Max Heat     : 1430.0312 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step F15======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 200.00 km
# 0001.000 Reached altitude of 197.02 km
# 0002.000 Reached altitude of 194.07 km
# 0003.000 Reached altitude of 191.14 km
# 0004.000 Reached altitude of 188.24 km
# 0005.000 Reached altitude of 185.38 km
# 0006.000 Reached altitude of 182.57 km
# 0007.000 Reached altitude of 179.80 km
# 0008.000 Reached altitude of 177.10 km
# 0009.000 Reached altitude of 174.45 km
# 0010.000 Reached altitude of 171.88 km
# 0011.000 Reached altitude of 169.39 km
# 0012.000 Reached altitude of 166.99 km
# 0013.000 Reached altitude of 164.69 km
# 0014.000 Reached altitude of 162.48 km
# 0015.000 Reached altitude of 160.38 km
# 0016.000 Reached altitude of 158.39 km
# 0017.000 Reached altitude of 156.51 km
# 0018.000 Reached altitude of 154.74 km
# 0019.000 Reached altitude of 153.08 km
# 0020.000 Reached altitude of 151.53 km
# 0021.000 Reached altitude of 150.08 km
# 0022.000 Reached altitude of 148.73 km
# 0023.000 Reached altitude of 147.47 km
# 0024.000 Reached altitude of 146.30 km
# 0025.000 Reached altitude of 145.21 km
# 0026.000 Reached altitude of 144.19 km
# 0027.000 Reached altitude of 143.24 km
# 0028.000 Reached altitude of 142.36 km
# 0029.000 Reached altitude of 141.54 km
# 0030.000 Reached altitude of 140.77 km
# 0031.000 Reached altitude of 140.05 km
# 0032.000 Reached altitude of 139.38 km
# 0033.000 Reached altitude of 138.75 km
# 0034.000 Reached altitude of 138.15 km
# 0035.000 Reached altitude of 137.60 km
# 0036.000 Reached altitude of 137.07 km
# 0037.000 Reached altitude of 136.57 km
# 0038.000 Reached altitude of 136.11 km
# 0039.000 Reached altitude of 135.66 km
# 0040.000 Reached altitude of 135.24 km
# 0041.000 Reached altitude of 134.84 km
# 0042.000 Reached altitude of 134.46 km
# 0043.000 Reached altitude of 134.10 km
# 0044.000 Reached altitude of 133.76 km
# 0045.000 Reached altitude of 133.43 km
# 0046.000 Reached altitude of 133.12 km
# 0047.000 Reached altitude of 132.82 km
# 0048.000 Reached altitude of 132.53 km
# 0049.000 Reached altitude of 132.26 km
# 0050.000 Reached altitude of 131.99 km
# 0051.000 Reached altitude of 131.74 km
# 0052.000 Reached altitude of 131.50 km
# 0053.000 Reached altitude of 131.26 km
# 0054.000 Reached altitude of 131.04 km
# 0055.000 Reached altitude of 130.82 km
# 0056.000 Reached altitude of 130.61 km
# 0057.000 Reached altitude of 130.41 km
# 0058.000 Reached altitude of 130.21 km
# 0059.000 Reached altitude of 130.03 km
# 0060.000 Reached altitude of 129.84 km
# 0061.000 Reached altitude of 129.67 km
# 0062.000 Reached altitude of 129.49 km
# 0063.000 Reached altitude of 129.33 km
# 0064.000 Reached altitude of 129.17 km
# 0065.000 Reached altitude of 129.01 km
# 0066.000 Reached altitude of 128.86 km
# 0067.000 Reached altitude of 128.71 km
# 0068.000 Reached altitude of 128.57 km
# 0069.000 Reached altitude of 128.43 km
# 0070.000 Reached altitude of 128.29 km
# 0071.000 Reached altitude of 128.16 km
# 0072.000 Reached altitude of 128.03 km
# 0073.000 Reached altitude of 127.90 km
# 0074.000 Reached altitude of 127.78 km
# 0075.000 Reached altitude of 127.66 km
# 0076.000 Reached altitude of 127.55 km
# 0077.000 Reached altitude of 127.43 km
# 0078.000 Reached altitude of 127.32 km
# 0079.000 Reached altitude of 127.21 km
# 0080.000 Reached altitude of 127.10 km
# 0081.000 Reached altitude of 127.00 km
# 0082.000 Reached altitude of 126.90 km
# 0083.000 Reached altitude of 126.80 km
# 0084.000 Reached altitude of 126.70 km
# 0085.000 Reached altitude of 126.61 km
# 0086.000 Reached altitude of 126.51 km
# 0087.000 Reached altitude of 126.42 km
# 0088.000 Reached altitude of 126.33 km
# 0089.000 Reached altitude of 126.24 km
# 0090.000 Reached altitude of 126.16 km
# 0091.000 Reached altitude of 126.07 km
# 0092.000 Reached altitude of 125.99 km
# 0093.000 Reached altitude of 125.91 km
# 0094.000 Reached altitude of 125.83 km
# 0095.000 Reached altitude of 125.75 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:03:16.803361
# End Time (real)       : 2025-06-04 20:06:07.054716
# Run Time (real)       : 170.251355 seconds
# Run Time (sim)        : 95.04 seconds
# Velocity              : 300.00 m/s
# Angle Distance        : 286.88 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 77.65 m/s
# Horizontal Velocity   : 289.78 m/s
# Vertical Distance     : 74.25 km
# Horizontal Distance   : 277.11 km
# Max Deceleration      : 48.34 g [Venus]
# Max Deceleration Time : 16.57 seconds
# Max Deceleration Alt  : 157.31 km
# Max Heat Flux         : 1050.04 W/cm2
# Max Heat Flux Time    : 8.90 seconds
# Max Heat Flux Alt     : 174.71 km
# Max Temperature       : -63.15 Degrees C
# Max Temperature Time  : 95.00 seconds
# Max Density           : 0.0229 kg/m3
# Max Density Time      : 95.03 seconds
# Lowest Altitude       : 125.75 km
# Lowest Altitude Time  : 95.04 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Numerical Acc. Peak   : -400.78 m/s/s
# Numerical Acc. Peak g : -45.18 g
# Total Heat Loading    : 0.0194 MJ/cm2
# Smoothed Max g        : 48.3095 g
# Smoothed Max Heat     : 1049.4327 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step F30======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 194.24 km
# 0002.000 Reached altitude of 188.55 km
# 0003.000 Reached altitude of 182.92 km
# 0004.000 Reached altitude of 177.40 km
# 0005.000 Reached altitude of 172.02 km
# 0006.000 Reached altitude of 166.82 km
# 0007.000 Reached altitude of 161.85 km
# 0008.000 Reached altitude of 157.17 km
# 0009.000 Reached altitude of 152.82 km
# 0010.000 Reached altitude of 148.86 km
# 0011.000 Reached altitude of 145.28 km
# 0012.000 Reached altitude of 142.11 km
# 0013.000 Reached altitude of 139.31 km
# 0014.000 Reached altitude of 136.87 km
# 0015.000 Reached altitude of 134.73 km
# 0016.000 Reached altitude of 132.87 km
# 0017.000 Reached altitude of 131.24 km
# 0018.000 Reached altitude of 129.80 km
# 0019.000 Reached altitude of 128.54 km
# 0020.000 Reached altitude of 127.42 km
# 0021.000 Reached altitude of 126.42 km
# 0022.000 Reached altitude of 125.53 km
# 0023.000 Reached altitude of 124.72 km
# 0024.000 Reached altitude of 123.99 km
# 0025.000 Reached altitude of 123.32 km
# 0026.000 Reached altitude of 122.71 km
# 0027.000 Reached altitude of 122.15 km
# 0028.000 Reached altitude of 121.64 km
# 0029.000 Reached altitude of 121.16 km
# 0030.000 Reached altitude of 120.72 km
# 0031.000 Reached altitude of 120.31 km
# 0032.000 Reached altitude of 119.92 km
# 0033.000 Reached altitude of 119.56 km
# 0034.000 Reached altitude of 119.22 km
# 0035.000 Reached altitude of 118.90 km
# 0036.000 Reached altitude of 118.60 km
# 0037.000 Reached altitude of 118.31 km
# 0038.000 Reached altitude of 118.04 km
# 0039.000 Reached altitude of 117.78 km
# 0040.000 Reached altitude of 117.54 km
# 0041.000 Reached altitude of 117.31 km
# 0042.000 Reached altitude of 117.09 km
# 0043.000 Reached altitude of 116.87 km
# 0044.000 Reached altitude of 116.67 km
# 0045.000 Reached altitude of 116.47 km
# 0046.000 Reached altitude of 116.29 km
# 0047.000 Reached altitude of 116.11 km
# 0048.000 Reached altitude of 115.94 km
# 0049.000 Reached altitude of 115.77 km
# 0050.000 Reached altitude of 115.61 km
# 0051.000 Reached altitude of 115.45 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:06:08.908443
# End Time (real)       : 2025-06-04 20:07:13.825004
# Run Time (real)       : 64.916561 seconds
# Run Time (sim)        : 51.35 seconds
# Velocity              : 300.00 m/s
# Angle Distance        : 169.19 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 150.00 m/s
# Horizontal Velocity   : 259.81 m/s
# Vertical Distance     : 84.60 km
# Horizontal Distance   : 146.53 km
# Max Deceleration      : 90.40 g [Venus]
# Max Deceleration Time : 10.54 seconds
# Max Deceleration Alt  : 146.88 km
# Max Heat Flux         : 1390.03 W/cm2
# Max Heat Flux Time    : 6.51 seconds
# Max Heat Flux Alt     : 164.24 km
# Max Temperature       : -6.55 Degrees C
# Max Temperature Time  : 25.85 seconds
# Max Density           : 0.0441 kg/m3
# Max Density Time      : 51.34 seconds
# Lowest Altitude       : 115.40 km
# Lowest Altitude Time  : 51.35 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Numerical Acc. Peak   : -774.24 m/s/s
# Numerical Acc. Peak g : -87.29 g
# Total Heat Loading    : 0.0150 MJ/cm2
# Smoothed Max g        : 90.2076 g
# Smoothed Max Heat     : 1387.1583 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step F45======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 191.86 km
# 0002.000 Reached altitude of 183.82 km
# 0003.000 Reached altitude of 175.92 km
# 0004.000 Reached altitude of 168.24 km
# 0005.000 Reached altitude of 160.89 km
# 0006.000 Reached altitude of 154.01 km
# 0007.000 Reached altitude of 147.75 km
# 0008.000 Reached altitude of 142.23 km
# 0009.000 Reached altitude of 137.49 km
# 0010.000 Reached altitude of 133.51 km
# 0011.000 Reached altitude of 130.21 km
# 0012.000 Reached altitude of 127.49 km
# 0013.000 Reached altitude of 125.24 km
# 0014.000 Reached altitude of 123.36 km
# 0015.000 Reached altitude of 121.77 km
# 0016.000 Reached altitude of 120.42 km
# 0017.000 Reached altitude of 119.26 km
# 0018.000 Reached altitude of 118.25 km
# 0019.000 Reached altitude of 117.36 km
# 0020.000 Reached altitude of 116.57 km
# 0021.000 Reached altitude of 115.87 km
# 0022.000 Reached altitude of 115.23 km
# 0023.000 Reached altitude of 114.66 km
# 0024.000 Reached altitude of 114.14 km
# 0025.000 Reached altitude of 113.66 km
# 0026.000 Reached altitude of 113.22 km
# 0027.000 Reached altitude of 112.82 km
# 0028.000 Reached altitude of 112.44 km
# 0029.000 Reached altitude of 112.09 km
# 0030.000 Reached altitude of 111.77 km
# 0031.000 Reached altitude of 111.46 km
# 0032.000 Reached altitude of 111.17 km
# 0033.000 Reached altitude of 110.90 km
# 0034.000 Reached altitude of 110.64 km
# 0035.000 Reached altitude of 110.40 km
# 0036.000 Reached altitude of 110.17 km
# 0037.000 Reached altitude of 109.95 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:07:15.451489
# End Time (real)       : 2025-06-04 20:07:55.813107
# Run Time (real)       : 40.361618 seconds
# Run Time (sim)        : 37.06 seconds
# Velocity              : 299.99 m/s
# Angle Distance        : 127.36 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 212.14 m/s
# Horizontal Velocity   : 212.14 m/s
# Vertical Distance     : 90.06 km
# Horizontal Distance   : 90.06 km
# Max Deceleration      : 126.55 g [Venus]
# Max Deceleration Time : 8.14 seconds
# Max Deceleration Alt  : 141.50 km
# Max Heat Flux         : 1627.91 W/cm2
# Max Heat Flux Time    : 5.30 seconds
# Max Heat Flux Alt     : 158.79 km
# Max Temperature       : -6.55 Degrees C
# Max Temperature Time  : 14.33 seconds
# Max Density           : 0.0623 kg/m3
# Max Density Time      : 37.06 seconds
# Lowest Altitude       : 109.94 km
# Lowest Altitude Time  : 37.06 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Numerical Acc. Peak   : -1094.95 m/s/s
# Numerical Acc. Peak g : -123.44 g
# Total Heat Loading    : 0.0130 MJ/cm2
# Smoothed Max g        : 126.0214 g
# Smoothed Max Heat     : 1621.3152 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step F60======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 190.03 km
# 0002.000 Reached altitude of 180.20 km
# 0003.000 Reached altitude of 170.58 km
# 0004.000 Reached altitude of 161.34 km
# 0005.000 Reached altitude of 152.69 km
# 0006.000 Reached altitude of 144.90 km
# 0007.000 Reached altitude of 138.20 km
# 0008.000 Reached altitude of 132.67 km
# 0009.000 Reached altitude of 128.23 km
# 0010.000 Reached altitude of 124.72 km
# 0011.000 Reached altitude of 121.93 km
# 0012.000 Reached altitude of 119.69 km
# 0013.000 Reached altitude of 117.87 km
# 0014.000 Reached altitude of 116.36 km
# 0015.000 Reached altitude of 115.10 km
# 0016.000 Reached altitude of 114.02 km
# 0017.000 Reached altitude of 113.08 km
# 0018.000 Reached altitude of 112.27 km
# 0019.000 Reached altitude of 111.55 km
# 0020.000 Reached altitude of 110.91 km
# 0021.000 Reached altitude of 110.33 km
# 0022.000 Reached altitude of 109.81 km
# 0023.000 Reached altitude of 109.34 km
# 0024.000 Reached altitude of 108.91 km
# 0025.000 Reached altitude of 108.51 km
# 0026.000 Reached altitude of 108.14 km
# 0027.000 Reached altitude of 107.80 km
# 0028.000 Reached altitude of 107.48 km
# 0029.000 Reached altitude of 107.18 km
# 0030.000 Reached altitude of 106.91 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:07:57.347898
# End Time (real)       : 2025-06-04 20:08:28.573626
# Run Time (real)       : 31.225728 seconds
# Run Time (sim)        : 30.61 seconds
# Velocity              : 300.00 m/s
# Angle Distance        : 107.68 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 259.82 m/s
# Horizontal Velocity   : 150.01 m/s
# Vertical Distance     : 93.25 km
# Horizontal Distance   : 53.84 km
# Max Deceleration      : 154.30 g [Venus]
# Max Deceleration Time : 7.00 seconds
# Max Deceleration Alt  : 138.21 km
# Max Heat Flux         : 1789.45 W/cm2
# Max Heat Flux Time    : 4.66 seconds
# Max Heat Flux Alt     : 155.57 km
# Max Temperature       : -6.62 Degrees C
# Max Temperature Time  : 10.66 seconds
# Max Density           : 0.0763 kg/m3
# Max Density Time      : 30.61 seconds
# Lowest Altitude       : 106.74 km
# Lowest Altitude Time  : 30.61 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Numerical Acc. Peak   : -1341.03 m/s/s
# Numerical Acc. Peak g : -151.19 g
# Total Heat Loading    : 0.0119 MJ/cm2
# Smoothed Max g        : 153.3384 g
# Smoothed Max Heat     : 1778.6325 W/cm2
#
# ====================================END OF SCRIPT======================================
#
#
# ====================================Call Step F75======================================
#
# ==================================SIMULATION START=====================================
# 0000.000 Reached altitude of 199.99 km
# 0001.000 Reached altitude of 188.89 km
# 0002.000 Reached altitude of 177.93 km
# 0003.000 Reached altitude of 167.25 km
# 0004.000 Reached altitude of 157.08 km
# 0005.000 Reached altitude of 147.74 km
# 0006.000 Reached altitude of 139.59 km
# 0007.000 Reached altitude of 132.87 km
# 0008.000 Reached altitude of 127.56 km
# 0009.000 Reached altitude of 123.45 km
# 0010.000 Reached altitude of 120.28 km
# 0011.000 Reached altitude of 117.80 km
# 0012.000 Reached altitude of 115.82 km
# 0013.000 Reached altitude of 114.22 km
# 0014.000 Reached altitude of 112.89 km
# 0015.000 Reached altitude of 111.77 km
# 0016.000 Reached altitude of 110.81 km
# 0017.000 Reached altitude of 109.98 km
# 0018.000 Reached altitude of 109.25 km
# 0019.000 Reached altitude of 108.61 km
# 0020.000 Reached altitude of 108.03 km
# 0021.000 Reached altitude of 107.51 km
# 0022.000 Reached altitude of 107.04 km
# 0023.000 Reached altitude of 106.61 km
# 0024.000 Reached altitude of 106.22 km
# 0025.000 Reached altitude of 105.85 km
# 0026.000 Reached altitude of 105.52 km
# 0027.000 Reached altitude of 105.20 km
#
# ==================================SIMULATION ENDED=====================================
#
# ====================================SUMMARY DATA=======================================
# Start Time (real)     : 2025-06-04 20:08:29.994624
# End Time (real)       : 2025-06-04 20:08:57.593998
# Run Time (real)       : 27.599374 seconds
# Run Time (sim)        : 27.61 seconds
# Velocity              : 299.99 m/s
# Angle Distance        : 98.33 km
# Acceleration          : 0.00 m/s/s
# Vertical Velocity     : 289.78 m/s
# Horizontal Velocity   : 77.65 m/s
# Vertical Distance     : 94.98 km
# Horizontal Distance   : 25.45 km
# Max Deceleration      : 171.74 g [Venus]
# Max Deceleration Time : 6.43 seconds
# Max Deceleration Alt  : 136.53 km
# Max Heat Flux         : 1883.96 W/cm2
# Max Heat Flux Time    : 4.33 seconds
# Max Heat Flux Alt     : 153.91 km
# Max Temperature       : -6.62 Degrees C
# Max Temperature Time  : 9.19 seconds
# Max Density           : 0.0850 kg/m3
# Max Density Time      : 27.61 seconds
# Lowest Altitude       : 105.02 km
# Lowest Altitude Time  : 27.61 seconds
# =======================================================================================
#
# =========================================PLOT==========================================
# Numerical Acc. Peak   : -1495.73 m/s/s
# Numerical Acc. Peak g : -168.63 g
# Total Heat Loading    : 0.0114 MJ/cm2
# Smoothed Max g        : 170.4203 g
# Smoothed Max Heat     : 1869.8699 W/cm2
#
# ====================================END OF SCRIPT======================================

# %%
#Store the output text
#with open(r'C:\Users\stuar\OneDrive\Open University\SXS841\Venus Entry Modelling\EntryAngleModelling.txt', 'w') as file:
#    file.write(cap.stdout)
